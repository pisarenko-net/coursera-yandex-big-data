# %%
# %%writefile create_external_db.hql
#
# USE demodb;
# DROP TABLE IF EXISTS posts_sample_external;
#
# CREATE EXTERNAL TABLE posts_sample_external (
#     id int,
#     year string,
#     month string
#
# )
# ROW FORMAT
#     SERDE 'org.apache.hadoop.hive.serde2.RegexSerDe'
#     WITH SERDEPROPERTIES (
#         "input.regex" = '^<row(?=.*\\bId="(\\d+)")(?=.*\\bCreationDate="(\\d{4})-(\\d{2})\\S*").*$'
#     )
# LOCATION '/data/stackexchange1000/posts';
# Out:
# Writing create_external_db.hql

# %%
# %%writefile create_partitioned_db.hql
#
# SET hive.exec.dynamic.partition=true;
# SET hive.exec.dynamic.partition.mode=nonstrict;
#
# USE demodb;
#
# DROP TABLE IF EXISTS posts_sample;
#
# CREATE TABLE posts_sample (
#    count int
# ) PARTITIONED BY (year string, month string);
#
# FROM posts_sample_external
# INSERT OVERWRITE TABLE posts_sample
# PARTITION (year, month)
# SELECT count(*), year, concat(year, '-', month) as month
# WHERE year IS NOT NULL
# GROUP BY year, concat(year, '-', month);
# Out:
# Writing create_partitioned_db.hql

# %%
# %%writefile query_3rd_row.hql
#
# USE demodb;
#
# SELECT year, month, count FROM (
#     SELECT * FROM (
#         SELECT
#             year,
#             month,
#             count,
#             ROW_NUMBER() OVER(ORDER BY year, month ASC) as rn
#         FROM posts_sample
#     ) AS t1
#     ORDER BY rn ASC
# ) AS t2
# WHERE rn='3';
# Out:
# Overwriting query_3rd_row.hql

# %%
! hive -f create_external_db.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 0.565 seconds
# OK
# Time taken: 0.719 seconds
# OK
# Time taken: 0.258 seconds

# %%
! hive -f create_partitioned_db.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 0.57 seconds
# OK
# Time taken: 2.001 seconds
# OK
# Time taken: 0.277 seconds
# Query ID = jovyan_20180519133434_0650f073-19b5-4516-b9b1-6e2438552367
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1526617807697_0014, Tracking URL = http://d8fa695eb221:8088/proxy/application_1526617807697_0014/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1526617807697_0014
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2018-05-19 13:34:21,928 Stage-1 map = 0%,  reduce = 0%
# 2018-05-19 13:34:36,509 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 14.0 sec
# 2018-05-19 13:34:46,890 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 18.8 sec
# MapReduce Total cumulative CPU time: 18 seconds 800 msec
# Ended Job = job_1526617807697_0014
# Loading data to table demodb.posts_sample partition (year=null, month=null)
# 	 Time taken for load dynamic partitions : 3937
# 	Loading partition {year=2008, month=2008-08}
# 	Loading partition {year=2014, month=2014-12}
# 	Loading partition {year=2015, month=2015-08}
# 	Loading partition {year=2015, month=2015-02}
# 	Loading partition {year=2014, month=2014-09}
# 	Loading partition {year=2010, month=2010-06}
# 	Loading partition {year=2009, month=2009-07}
# 	Loading partition {year=2016, month=2016-07}
# 	Loading partition {year=2009, month=2009-10}
# 	Loading partition {year=2013, month=2013-04}
# 	Loading partition {year=2014, month=2014-03}
# 	Loading partition {year=2016, month=2016-10}
# 	Loading partition {year=2009, month=2009-01}
# 	Loading partition {year=2016, month=2016-01}
# 	Loading partition {year=2008, month=2008-11}
# 	Loading partition {year=2015, month=2015-11}
# 	Loading partition {year=2009, month=2009-08}
# 	Loading partition {year=2016, month=2016-08}
# 	Loading partition {year=2009, month=2009-02}
# 	Loading partition {year=2016, month=2016-02}
# 	Loading partition {year=2008, month=2008-10}
# 	Loading partition {year=2015, month=2015-10}
# 	Loading partition {year=2015, month=2015-03}
# 	Loading partition {year=2008, month=2008-09}
# 	Loading partition {year=2014, month=2014-11}
# 	Loading partition {year=2015, month=2015-09}
# 	Loading partition {year=2013, month=2013-12}
# 	Loading partition {year=2010, month=2010-10}
# 	Loading partition {year=2011, month=2011-10}
# 	Loading partition {year=2012, month=2012-06}
# 	Loading partition {year=2011, month=2011-01}
# 	Loading partition {year=2014, month=2014-04}
# 	Loading partition {year=2012, month=2012-09}
# 	Loading partition {year=2009, month=2009-03}
# 	Loading partition {year=2016, month=2016-03}
# 	Loading partition {year=2013, month=2013-02}
# 	Loading partition {year=2010, month=2010-08}
# 	Loading partition {year=2012, month=2012-12}
# 	Loading partition {year=2011, month=2011-04}
# 	Loading partition {year=2010, month=2010-01}
# 	Loading partition {year=2009, month=2009-11}
# 	Loading partition {year=2013, month=2013-09}
# 	Loading partition {year=2016, month=2016-11}
# 	Loading partition {year=2012, month=2012-10}
# 	Loading partition {year=2011, month=2011-06}
# 	Loading partition {year=2015, month=2015-07}
# 	Loading partition {year=2010, month=2010-12}
# 	Loading partition {year=2011, month=2011-12}
# 	Loading partition {year=2014, month=2014-07}
# 	Loading partition {year=2012, month=2012-04}
# 	Loading partition {year=2014, month=2014-02}
# 	Loading partition {year=2009, month=2009-05}
# 	Loading partition {year=2016, month=2016-05}
# 	Loading partition {year=2015, month=2015-05}
# 	Loading partition {year=2009, month=2009-04}
# 	Loading partition {year=2016, month=2016-04}
# 	Loading partition {year=2013, month=2013-10}
# 	Loading partition {year=2010, month=2010-03}
# 	Loading partition {year=2012, month=2012-11}
# 	Loading partition {year=2013, month=2013-01}
# 	Loading partition {year=2012, month=2012-08}
# 	Loading partition {year=2013, month=2013-07}
# 	Loading partition {year=2014, month=2014-06}
# 	Loading partition {year=2013, month=2013-06}
# 	Loading partition {year=2010, month=2010-04}
# 	Loading partition {year=2014, month=2014-05}
# 	Loading partition {year=2011, month=2011-03}
# 	Loading partition {year=2011, month=2011-09}
# 	Loading partition {year=2015, month=2015-04}
# 	Loading partition {year=2012, month=2012-01}
# 	Loading partition {year=2014, month=2014-10}
# 	Loading partition {year=2011, month=2011-02}
# 	Loading partition {year=2011, month=2011-08}
# 	Loading partition {year=2012, month=2012-02}
# 	Loading partition {year=2010, month=2010-09}
# 	Loading partition {year=2012, month=2012-07}
# 	Loading partition {year=2012, month=2012-03}
# 	Loading partition {year=2010, month=2010-11}
# 	Loading partition {year=2011, month=2011-07}
# 	Loading partition {year=2013, month=2013-05}
# 	Loading partition {year=2010, month=2010-02}
# 	Loading partition {year=2016, month=2016-12}
# 	Loading partition {year=2009, month=2009-12}
# 	Loading partition {year=2013, month=2013-08}
# 	Loading partition {year=2016, month=2016-06}
# 	Loading partition {year=2009, month=2009-09}
# 	Loading partition {year=2013, month=2013-11}
# 	Loading partition {year=2016, month=2016-09}
# 	Loading partition {year=2014, month=2014-01}
# 	Loading partition {year=2009, month=2009-06}
# 	Loading partition {year=2010, month=2010-05}
# 	Loading partition {year=2010, month=2010-07}
# 	Loading partition {year=2008, month=2008-12}
# 	Loading partition {year=2015, month=2015-12}
# 	Loading partition {year=2011, month=2011-11}
# 	Loading partition {year=2012, month=2012-05}
# 	Loading partition {year=2014, month=2014-08}
# 	Loading partition {year=2011, month=2011-05}
# 	Loading partition {year=2015, month=2015-01}
# 	Loading partition {year=2015, month=2015-06}
# 	Loading partition {year=2013, month=2013-03}
# 	 Time taken for adding to write entity : 18
# Partition demodb.posts_sample{year=2008, month=2008-08} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2008, month=2008-09} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2008, month=2008-10} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2008, month=2008-11} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2008, month=2008-12} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2009, month=2009-01} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2009, month=2009-02} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2009, month=2009-03} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2009, month=2009-04} stats: [numFiles=1, numRows=1, totalSize=3, rawDataSize=2]
# Partition demodb.posts_sample{year=2009, month=2009-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2009, month=2009-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2010, month=2010-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2011, month=2011-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2012, month=2012-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2013, month=2013-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2014, month=2014-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2015, month=2015-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-01} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-02} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-03} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-04} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-05} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-06} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-07} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-08} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-09} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-10} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-11} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# Partition demodb.posts_sample{year=2016, month=2016-12} stats: [numFiles=1, numRows=1, totalSize=4, rawDataSize=3]
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 18.8 sec   HDFS Read: 60007524 HDFS Write: 6694 SUCCESS
# Total MapReduce CPU Time Spent: 18 seconds 800 msec
# OK
# Time taken: 39.094 seconds

# %%
! hive -f query_3rd_row.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 0.545 seconds
# Query ID = jovyan_20180519134545_c2ea49a5-4277-4962-9ef2-8007d5516300
# Total jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1526617807697_0016, Tracking URL = http://d8fa695eb221:8088/proxy/application_1526617807697_0016/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1526617807697_0016
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2018-05-19 13:45:20,443 Stage-1 map = 0%,  reduce = 0%
# 2018-05-19 13:45:25,657 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 2.16 sec
# 2018-05-19 13:45:31,944 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 4.29 sec
# MapReduce Total cumulative CPU time: 4 seconds 290 msec
# Ended Job = job_1526617807697_0016
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1526617807697_0017, Tracking URL = http://d8fa695eb221:8088/proxy/application_1526617807697_0017/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1526617807697_0017
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2018-05-19 13:45:44,812 Stage-2 map = 0%,  reduce = 0%
# 2018-05-19 13:45:50,017 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 1.06 sec
# 2018-05-19 13:45:55,256 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 2.72 sec
# MapReduce Total cumulative CPU time: 2 seconds 720 msec
# Ended Job = job_1526617807697_0017
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 4.29 sec   HDFS Read: 49708 HDFS Write: 128 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 2.72 sec   HDFS Read: 4832 HDFS Write: 16 SUCCESS
# Total MapReduce CPU Time Spent: 7 seconds 10 msec
# OK
# 2008	2008-10	73
# Time taken: 44.429 seconds, Fetched: 1 row(s)
